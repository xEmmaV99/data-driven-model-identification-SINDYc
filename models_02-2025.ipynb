# %%
import os.path
from optimize_parameters import plot_optuna_data
from source import *
from train_model_source import simulate_model, make_model
# %matplotlib QtAgg

def plot_function(models,testdata, type, existing_plot, folder):
    pref = "_feb//"
    if not existing_plot:
        for model in models:
            do_sim = type=='currents'
            sim, test = simulate_model(pref + model + '_model', testdata, 
                                       modeltype=type, do_time_simulation=do_sim,
                                       show=False, ecc_input = True)
    else:
        show_coefs = True
        if show_coefs:
            for model_ in models:
                model = load_model(pref + model_ + '_model')
                plot_coefs2(model, log=True, type=type)
        path = os.path.join(os.getcwd(), 'plot_data//_feb//', folder)
        plot_everything(path)

# %%
## currents 0
plot_optuna_data('models_februari//currentsnonlinear-optuna-study')
# Out:
# [I 2025-05-26 09:34:36,672] Study name was omitted but trying to load 'optuna_studies//currentsnonlinear-optuna-study' because that was the only study found in the storage.
# ['optuna_studies//currentsnonlinear-optuna-study']
# Trial count: 498

# %%
traindata = os.path.join(os.getcwd(), 'train-data', '07-31-nonlin', 'IMMEC_nonlinear-0ecc_5.0sec.npz')
## this model turns out not to be good
#model = make_model(traindata, modeltype='currents', optimizer='lasso',
#               nmbr_of_train=-1, lib='interaction_only', alpha = 71.275,
#               modelname='currents_85', ecc_input = False)
# sparsity 85, mse 220

#model = make_model(traindata, modeltype='currents', optimizer='STLSQ',
#               nmbr_of_train=-1, lib='linear-specific', alpha = .000989657, threshold = 0.5435,
#               modelname='currents_70')

print("trial number 433")
model =  make_model(traindata, modeltype='currents', optimizer='STLSQ',
               nmbr_of_train=-1, lib='linear-specific', alpha = 0.1203422,threshold = 0.7496,
                    modelname='currents_70')

# %%
testdata = os.path.join(os.getcwd(), 'test-data', '08-07', 'IMMEC_nonlin_0ecc_5.0sec.npz')

models = ['currents_70a'] #['currents_85']

plot_function(models, testdata, 'currents', True, 'currents_nl')
# Out:
# (i_d)' = -42.825 i_d + 896.620 i_q + 9.441 v_d + -59.261 v_q + -22.500 v_0 + 399.253 I_d + 5379.612 I_q + 111.954 V_d + -856.196 V_q + 599.867 V_0 + 1.905 \gamma I_d + -8.046 \gamma I_q + -190.804 \gamma V_0 + -0.802 \omega i_q + -503.887 \omega I_d + 12.678 \omega I_q + 66.572 \omega V_d + 2.764 \omega V_q + 46.293 v_d I_d + 73.751 v_d I_q + -15.162 v_d V_d + -8.047 v_d V_q + -1.473 v_d V_0 + -62.177 v_q I_d + 47.055 v_q I_q + 7.906 v_q V_d + -15.283 v_q V_q + -8.599 v_q V_0 + 0.967 v_0 i_d + 15.740 v_0 I_d + 172.300 v_0 I_q + 2.885 v_0 V_q + -33.422 v_0 V_0
# (i_q)' = -801.443 i_d + -93.270 i_q + 138.893 v_d + 43.007 v_q + -12.299 v_0 + -4517.353 I_d + -25.367 I_q + 654.661 V_d + 213.981 V_q + -209.767 V_0 + 1.377 \gamma i_d + -2.026 \gamma i_q + -35.155 \gamma I_d + 45.475 \gamma I_q + 5.318 \gamma V_q + -26.253 \gamma V_0 + 16.493 \omega I_d + -509.638 \omega I_q + -3.045 \omega V_d + 76.428 \omega V_q + 1.280 \omega V_0 + 12.720 v_d I_d + 25.004 v_d I_q + -59.697 v_d V_d + -2.564 v_d V_q + -3.525 v_d V_0 + -20.496 v_q I_d + 16.373 v_q I_q + 2.524 v_q V_d + -59.794 v_q V_q + -4.441 v_q V_0 + -8.254 v_0 I_d + 101.741 v_0 I_q + 2.202 v_0 V_d + 1.246 v_0 V_q + 81.367 v_0 V_0
# (i_0)' = 0.000
# Sparsity:  69
# C:\Users\emmav\PycharmProjects\SINDY_project\source.py:737: SyntaxWarning:
#
# invalid escape sequence '\m'
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 5
#       1 testdata = os.path.join(os.getcwd(), 'test-data', '08-07', 'IMMEC_nonlin_0ecc_5.0sec.npz')
#       3 models = ['currents_70a'] #['currents_85']
# ----> 5 plot_function(models, testdata, 'currents', True, 'currents_nl')
#
# Cell In[1], line 22, in plot_function(models, testdata, type, existing_plot, folder)
#      20         plot_coefs2(model, log=True, type=type)
#      21 path = os.path.join(os.getcwd(), 'plot_data//_feb//', folder)
# ---> 22 plot_everything(path)
#
# File ~\PycharmProjects\SINDY_project\source.py:532, in plot_everything(path_to_directory)
#     527 def plot_everything(path_to_directory: str):
#     528     """
#     529     Plots every file from a folder
#     530     :param path_to_directory:  path to a folder
#     531     :return:
# --> 532     """
#     533     files = os.listdir(path_to_directory)
#     534     for file in files:
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'C:\\Users\\emmav\\PycharmProjects\\SINDY_project\\plot_data//_feb//currents_nl'

# %%
## torque 0
plot_optuna_data('models_februari//torquenonlinear-optuna-study')

# %%
traindata = os.path.join(os.getcwd(), 'train-data', '07-31-nonlin', 'IMMEC_nonlinear-0ecc_5.0sec.npz')
print("trial number 477")
model = make_model(traindata, modeltype='torque', optimizer='STLSQ',
               nmbr_of_train=-1, lib='poly_2nd_order', alpha = 2.11237, threshold = 0.3869,
               modelname='torque_5')

# %%
testdata = os.path.join(os.getcwd(), 'test-data', '08-07', 'IMMEC_nonlin_0ecc_5.0sec.npz')

models = ['torque_5']

plot_function(models, testdata, 'torque', False, 'torque_nl')

# %%
## currents 50

# %%
plot_optuna_data('models_februari//currentsnonlinear_50ecc-optuna-study')
# Out:
# [I 2025-05-28 09:42:11,829] Study name was omitted but trying to load 'optuna_studies//currentsnonlinear_50ecc-optuna-study' because that was the only study found in the storage.
# ['optuna_studies//currentsnonlinear_50ecc-optuna-study']
# Trial count: 498

# %%
traindata = os.path.join(os.getcwd(), 'train-data', '07-31-nonlin50', 'IMMEC_nonlinear-50ecc_5.0sec.npz')
#print("trial number unknown")
#model=  make_model(traindata, modeltype='currents', optimizer ="STLSQ",
#                    nmbr_of_train=-1, lib='linear-specific', alpha = 0.000178, threshold = 0.0216,
#                    modelname='currents_50ecc_70')

#print("trial number 431")
#model=  make_model(traindata, modeltype='currents', optimizer ="STLSQ",
#                    nmbr_of_train=-1, lib='linear-specific', alpha = 0.0001118, threshold = 0.50819,
#                    modelname='currents_50ecc_70')

print('trial

# %%
testdata = os.path.join(os.getcwd(), 'test-data', '08-07-nonlin-50ecc', 'IMMEC_nonlin_50ecc_5.0sec.npz')

models = ['currents_e_70a'] #, 'currents_nonlinear_50ecc_100', currents_nonlinear_50ecc_260']

plot_function(models, testdata, 'currents', False, 'currents_50_nl')
# Out:
# (i_d)' = -81.899 i_d + 758.303 i_q + 14.210 v_d + -47.030 v_q + -31.087 v_0 + 100.368 I_d + 4599.850 I_q + 156.926 V_d + -702.764 V_q + 1512.226 V_0 + -0.841 \gamma i_d + 9.682 \gamma I_d + -32.971 \gamma I_q + -186.901 \gamma V_0 + -0.769 \omega i_q + -438.780 \omega I_d + -16.122 \omega I_q + 55.654 \omega V_d + 7.130 \omega V_q + -8.541 \omega V_0 + 49.435 v_d I_d + 78.786 v_d I_q + -16.302 v_d V_d + -8.399 v_d V_q + -2.108 v_d V_0 + -70.664 v_q I_d + 50.864 v_q I_q + 8.348 v_q V_d + -16.412 v_q V_q + -3.489 v_q V_0 + 133.184 v_0 I_d + 80.332 v_0 I_q + 0.911 v_0 V_d + -0.730 v_0 V_q + -53.756 v_0 V_0
# (i_q)' = -675.882 i_d + -34.505 i_q + 63.445 v_d + 6.125 v_q + -4.726 v_0 + -4556.187 I_d + 89.379 I_q + 706.044 V_d + 111.184 V_q + 1104.423 V_0 + 0.744 \gamma i_d + -1.834 \gamma i_q + -65.806 \gamma I_d + 67.276 \gamma I_q + 1.674 \gamma V_d + 5.315 \gamma V_q + 3.325 \gamma V_0 + 0.792 \omega i_d + -5.214 \omega I_d + -355.220 \omega I_q + 55.399 \omega V_q + -3.113 \omega V_0 + 12.055 v_d I_d + 14.038 v_d I_q + -9.731 v_d V_d + -1.309 v_d V_q + -2.278 v_d V_0 + -12.846 v_q I_d + 15.367 v_q I_q + 1.339 v_q V_d + -9.780 v_q V_q + 9.644 v_0 I_d + 28.825 v_0 I_q + 0.987 v_0 V_d + -8.987 v_0 V_0
# (i_0)' = 0.000
# ecc input:  True
# Loading data
# Done loading data
# Calculating xdots
# Assume all t_vec are equal for all simulations
# Done calculating xdots
# MSE on test:  1852.1132093561694
# Non-zero elements:  70
# Starting time simulation, max 0.7
# Finished simulation
# (7000, 3)
# (7000, 3)
# MSE on simulation:  0.0024086637255197455

# %%
## torque 50

# %%
plot_optuna_data('models_februari//torquenonlinear_50ecc-optuna-study')

# %%
traindata = os.path.join(os.getcwd(), 'train-data', '07-31-nonlin50', 'IMMEC_nonlinear-50ecc_5.0sec.npz')
print("trial number: 316")
model =  make_model(traindata, modeltype='torque', optimizer ="STLSQ",
                    nmbr_of_train=-1, lib='poly_2nd_order', alpha = 1.238025, threshold = 0.01006,
                    modelname='torque_e_40')

# %%
testdata = os.path.join(os.getcwd(), 'test-data', '08-07-nonlin-50ecc', 'IMMEC_nonlin_50ecc_5.0sec.npz')

models = ['torque_e_40']

plot_function(models, testdata, 'torque', False, 'torque')
# Out:
# (i_d)' = -0.004 1 + -0.531 i_d + 0.389 i_q + 0.035 v_d + -0.030 v_q + -5.054 I_d + 2.891 I_q + 3.428 V_d + 1.111 V_q + -0.520 V_0 + -0.031 \omega + 1.601 i_d I_d + 7.443 i_d I_q + -0.034 i_d V_d + -0.773 i_d V_q + -0.372 i_d V_0 + -7.491 i_q I_d + 0.893 i_q I_q + 0.786 i_q V_d + -0.028 i_q V_q + 0.949 i_q V_0 + -0.065 v_d I_d + -0.102 v_d I_q + -0.020 v_d V_q + 0.079 v_q I_d + -0.057 v_q I_q + 0.020 v_q V_d + -0.271 v_0 V_0 + 13.574 I_d^2 + -1.882 I_d V_d + 3.531 I_d V_q + 7.827 I_q^2 + -3.370 I_q V_d + -0.999 I_q V_q + 16.087 I_q V_0 + -0.013 I_q \omega + -1.253 V_d^2 + -1.267 V_q^2 + -1.763 V_q V_0
# ecc input:  True
# Loading data
# Done loading data
# Calculating xdots
# Assume all t_vec are equal for all simulations
# Done calculating xdots
# MSE on test:  0.0001402395262547556
# Non-zero elements:  39
# MSE simplified model 0.0010157872638280811

# %%
## ump 50

# %%
plot_optuna_data('models_februari//umpnonlinear_50ecc-optuna-study') #trial 240

# %%
traindata = os.path.join(os.getcwd(), 'train-data', '07-31-nonlin50', 'IMMEC_nonlinear-50ecc_5.0sec.npz')
print("trial number 240")
model =  make_model(traindata, modeltype='ump', optimizer ="STLSQ",
                    nmbr_of_train=-1, lib='poly_2nd_order', alpha = 1.412438, threshold = 0.2399,
                    modelname='ump_e_100')

# %%
testdata = os.path.join(os.getcwd(), 'test-data', '08-07-nonlin-50ecc', 'IMMEC_nonlin_50ecc_5.0sec.npz')

models = ['ump_e_100']

plot_function(models, testdata, 'ump', False, 'ump_50_nl')
# Out:
# (i_d)' = 0.366 1 + 34.794 i_d + 146.686 i_q + -14.018 v_d + -1.843 v_q + -50.318 v_0 + -3019.993 I_d + 6594.430 I_q + 193.272 V_d + -1098.334 V_q + 16501.919 V_0 + -4.644 \omega + -8.357 i_d i_q + 0.283 i_d v_q + -1.231 i_d v_0 + 578.609 i_d I_d + -202.144 i_d I_q + -59.950 i_d V_d + -74.634 i_d V_q + 163.455 i_d V_0 + 29.464 i_q^2 + -0.221 i_q v_d + -1.272 i_q v_0 + -243.579 i_q I_d + 28.310 i_q I_q + -16.242 i_q V_d + -145.711 i_q V_q + -339.774 i_q V_0 + 33.706 v_d I_d + 92.999 v_d I_q + -2.411 v_d V_q + 4.879 v_d V_0 + -11.592 v_q I_d + 17.876 v_q I_q + 2.385 v_q V_d + 3.028 v_q V_0 + 233.660 v_0 I_d + 52.616 v_0 I_q + 3.468 v_0 V_d + -0.334 v_0 V_q + -176.518 v_0 V_0 + 11236.655 I_d^2 + 1026.088 I_d I_q + -3366.165 I_d V_d + 3798.946 I_d V_q + -108494.951 I_d V_0 + 1.568 I_d \omega + -11939.678 I_q^2 + -3417.513 I_q V_d + -1168.108 I_q V_q + -11192.809 I_q V_0 + 3.288 I_q \omega + 329.368 V_d^2 + 54.623 V_d V_q + 852.822 V_d V_0 + -0.577 V_d \omega + 392.832 V_q^2 + 4501.475 V_q V_0 + 66180.081 V_0^2 + 0.219 sin(1 \gamma) + 0.273 cos(1 \gamma)
# (i_q)' = -3.037 1 + -126.253 i_d + -149.260 i_q + -12.855 v_d + -0.490 v_q + 17.707 v_0 + 2737.986 I_d + 4511.785 I_q + -34.056 V_d + -362.677 V_q + 3919.213 V_0 + 0.169 \omega + -2.197 i_d^2 + -11.138 i_d i_q + -0.793 i_d v_0 + 1036.428 i_d I_d + -687.280 i_d I_q + 49.725 i_d V_d + -73.772 i_d V_q + -16.344 i_d V_0 + 1.568 i_q^2 + 269.676 i_q I_d + 588.410 i_q I_q + 38.895 i_q V_d + -5.890 i_q V_q + 842.827 i_q V_0 + -31.578 v_d I_d + 102.696 v_d I_q + 7.113 v_d V_d + -32.143 v_q I_d + 16.006 v_q I_q + 7.037 v_q V_q + -5.321 v_q V_0 + -23.484 v_0 I_d + -130.620 v_0 I_q + -270.830 v_0 V_0 + -23064.717 I_d^2 + 9415.744 I_d I_q + 3662.011 I_d V_d + 651.476 I_d V_q + -35186.862 I_d V_0 + 1.849 I_d \omega + -38447.698 I_q^2 + -1461.030 I_q V_d + 5057.869 I_q V_q + 7176.689 I_q V_0 + -6.844 I_q \omega + -212.951 V_d^2 + 1.332 V_d V_q + 1783.877 V_d V_0 + -214.513 V_q^2 + -605.080 V_q V_0 + -37017.801 V_0^2 + 0.184 sin(1 \gamma)
# ecc input:  True
# Loading data
# Done loading data
# Calculating xdots
# Assume all t_vec are equal for all simulations
# Done calculating xdots
# MSE on test:  41.35679456035176
# Non-zero elements:  115

# %%
## currents dyn

# %%
plot_optuna_data('models_februari//currentsnonlinear_dynamic_50ecc-optuna-study') # 433
# Out:
# [I 2025-05-26 09:55:56,337] Study name was omitted but trying to load 'optuna_studies//currentsnonlinear_dynamic_50ecc-optuna-study' because that was the only study found in the storage.
# ['optuna_studies//currentsnonlinear_dynamic_50ecc-optuna-study']
# Trial count: 498

# %%
traindata = os.path.join(os.getcwd(), 'train-data', '08-16','IMMEC_dynamic_nonlinear_5.0sec.npz')
print('trial number: 433')
model = make_model(traindata, modeltype='currents', optimizer="STLSQ", alpha=8.1443, threshold = 0.222825,
                    nmbr_of_train=-1, lib='linear-specific', modelname='currents_ed_70')

# %%
testdata = os.path.join(os.getcwd(), 'test-data','08-18','IMMEC_dynamic_nonlinear_5.0sec.npz')
models = ['currents_ed_70']
plot_function(models, testdata, 'currents', True, 'currents_d_nl')
# Out:
# (i_d)' = -41.822 i_d + 762.192 i_q + 8.648 v_d + -54.650 v_q + -3.501 v_0 + 534.454 I_d + 4102.636 I_q + 110.875 V_d + -628.318 V_q + 31.493 V_0 + 0.758 \gamma i_d + -0.140 \gamma i_q + 51.533 \gamma I_d + -61.132 \gamma I_q + -2.966 \gamma V_d + -15.205 \gamma V_0 + -0.514 \omega i_q + -484.387 \omega I_d + 14.274 \omega I_q + 61.497 \omega V_d + 2.482 \omega V_q + 54.134 v_d I_d + 79.093 v_d I_q + -15.261 v_d V_d + -9.283 v_d V_q + -71.527 v_q I_d + 53.442 v_q I_q + 9.256 v_q V_d + -15.337 v_q V_q + -0.618 v_q V_0 + 0.224 v_0 i_d + -7.204 v_0 I_d + 43.823 v_0 I_q + 0.272 v_0 V_q + -16.887 v_0 V_0
# (i_q)' = -713.774 i_d + -62.073 i_q + 94.722 v_d + 19.067 v_q + -1.752 v_0 + -3320.444 I_d + 756.403 I_q + 492.346 V_d + 93.459 V_q + 106.048 V_0 + 1.459 \gamma i_d + -2.641 \gamma i_q + 32.820 \gamma I_d + -60.578 \gamma I_q + -1.816 \gamma V_d + 4.808 \gamma V_q + -57.754 \gamma V_0 + 20.188 \omega I_d + -500.244 \omega I_q + 69.630 \omega V_q + 0.362 \omega V_0 + 22.414 v_d I_d + 25.932 v_d I_q + -27.620 v_d V_d + -2.185 v_d V_q + -22.634 v_q I_d + 25.589 v_q I_q + 2.204 v_q V_d + -27.659 v_q V_q + 6.636 v_0 I_d + 5.684 v_0 I_q + 16.884 v_0 V_0
# (i_0)' = 0.000
# Sparsity:  67
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 3
#       1 testdata = os.path.join(os.getcwd(), 'test-data','08-18','IMMEC_dynamic_nonlinear_5.0sec.npz')
#       2 models = ['currents_ed_70']
# ----> 3 plot_function(models, testdata, 'currents', True, 'currents_d_nl')
#
# Cell In[1], line 22, in plot_function(models, testdata, type, existing_plot, folder)
#      20         plot_coefs2(model, log=True, type=type)
#      21 path = os.path.join(os.getcwd(), 'plot_data//_feb//', folder)
# ---> 22 plot_everything(path)
#
# File ~\PycharmProjects\SINDY_project\source.py:532, in plot_everything(path_to_directory)
#     527 def plot_everything(path_to_directory: str):
#     528     """
#     529     Plots every file from a folder
#     530     :param path_to_directory:  path to a folder
#     531     :return:
# --> 532     """
#     533     files = os.listdir(path_to_directory)
#     534     for file in files:
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'C:\\Users\\emmav\\PycharmProjects\\SINDY_project\\plot_data//_feb//currents_d_nl'

# %%
## torque dyn (SMALL DIFFERENCE HERE)

# %%
plot_optuna_data('models_februari///torquenonlinear_dynamic_50ecc-optuna-study') #473, 374
# Out:
# [I 2025-02-26 18:36:48,809] Study name was omitted but trying to load 'optuna_studies//torquenonlinear_dynamic_50ecc-optuna-study' because that was the only study found in the storage.
# ['optuna_studies//torquenonlinear_dynamic_50ecc-optuna-study']
# Trial count: 498

# %%
traindata = os.path.join(os.getcwd(), 'train-data', '08-16','IMMEC_dynamic_nonlinear_5.0sec.npz')
#print('Trial number:473 ')
#model1 =  make_model(traindata, modeltype='torque', optimizer ="STLSQ",
#                    nmbr_of_train=-1, lib='poly_2nd_order', alpha = 48.189, threshold= 0.0014,
#                    modelname='torque_ed_50')
print('Trial number: 374')
model1 =  make_model(traindata, modeltype='torque', optimizer ="STLSQ",
                    nmbr_of_train=-1, lib='poly_2nd_order', alpha = 9.095623, threshold= 0.00354,
                    modelname='torque_ed_40')

# %%
testdata = os.path.join(os.getcwd(), 'test-data','08-18','IMMEC_dynamic_nonlinear_5.0sec.npz')

#models = ['torque_ed_50']
models = ['torque_ed_40']
plot_function(models, testdata, 'torque', False, 'torque_d_nl')
# Out:
# (i_d)' = 0.007 1 + 0.880 i_q + 0.031 v_d + -0.039 v_q + -3.572 I_d + 3.304 I_q + 2.008 V_d + 0.262 V_q + -0.042 V_0 + -0.003 i_d^2 + -0.005 i_d i_q + -3.097 i_d I_d + 9.696 i_d I_q + -0.009 i_d V_d + -0.753 i_d V_q + -8.282 i_q I_d + -2.645 i_q I_q + 0.818 i_q V_d + -0.087 i_q V_q + -0.185 i_q V_0 + -0.040 v_d I_d + -0.268 v_d I_q + 0.004 v_d V_d + 0.206 v_q I_d + 0.004 v_q V_q + 0.011 v_0 I_d + -0.018 v_0 I_q + -0.176 v_0 V_0 + 21.501 I_d I_q + -0.780 I_d V_d + 3.222 I_d V_q + 0.020 I_d \omega + 5.968 I_q^2 + -6.320 I_q V_d + -2.079 I_q V_q + -0.036 I_q \omega + -0.562 V_d^2 + 0.016 V_d V_q + -0.498 V_q^2 + 0.052 V_q V_0 + 68.055 V_0^2
# ecc input:  True
# Loading data
# Done loading data
# Calculating xdots
# Assume all t_vec are equal for all simulations
# Done calculating xdots
# MSE on test:  0.0011341347828512068
# Non-zero elements:  41
# MSE simplified model 0.00154148839834995

# %%
## ump dyn

# %%
plot_optuna_data('models_februari//umpnonlinear_dynamic_50ecc-optuna-study') #323, 298, 415
# Out:
# [I 2025-02-27 11:22:13,008] Study name was omitted but trying to load 'optuna_studies//umpnonlinear_dynamic_50ecc-optuna-study' because that was the only study found in the storage.
# ['optuna_studies//umpnonlinear_dynamic_50ecc-optuna-study']
# Trial count: 498

# %%
traindata = os.path.join(os.getcwd(), 'train-data', '08-16','IMMEC_dynamic_nonlinear_5.0sec.npz')
#print('trial number 323')
#model =  make_model(traindata, modeltype='ump', optimizer ="STLSQ",
#                    nmbr_of_train=-1, lib='poly_2nd_order', alpha = 0.7976, threshold = 0.0020,
#                   modelname='ump_ed_150')
#print('trial number 298')
#model =  make_model(traindata, modeltype='ump', optimizer ="sr3",
#                    nmbr_of_train=-1, lib='poly_2nd_order', lamb = 5.716 , nu = 5.2345e-10,
#                   modelname='ump_ed_160')
print('trial number 415')
model = make_model(traindata, modeltype='ump', optimizer ="STLSQ",
                   nmbr_of_train=-1, lib='nonlinear_terms', alpha=7.38e-5, threshold = 0.001588,
                   modelname='ump_ed_460')

# %%
testdata = os.path.join(os.getcwd(), 'test-data','08-18','IMMEC_dynamic_nonlinear_5.0sec.npz')

#models = ['ump_ed_150']
models = ['ump_ed_160']
#models = ['ump_ed_460']

plot_function(models, testdata, 'ump', False, 'ump_d_nl')

# %%
## REFERENCE: UMP model 0!!
traindata = os.path.join(os.getcwd(), 'train-data', '07-31-nonlin', 'IMMEC_nonlinear-0ecc_5.0sec.npz')
plot_optuna_data('models_februari//umpnonlinear-optuna-study')

# %%
print("trial number= 494")
model = make_model(traindata, modeltype='ump', optimizer ="lasso",
                   nmbr_of_train=-1, lib='torque', alpha=13.350245,
                   modelname='ump_0')

# %%
testdata = os.path.join(os.getcwd(), 'test-data', '08-07', 'IMMEC_nonlin_0ecc_5.0sec.npz')
models = ['ump_0']

plot_function(models, testdata, 'ump', False, 'ump_0')
# Out:
# C:\Users\emmav\anaconda3\envs\sindy_abstract\Lib\site-packages\pysindy\feature_library\generalized_library.py:101: UserWarning:
#
# inputs_per_library should no longer be passed as a numpy array
# (i_d)' = 0.000
# (i_q)' = 0.000
# ecc input:  True
# Loading data
# Done loading data
# Calculating xdots
# Assume all t_vec are equal for all simulations
# Done calculating xdots
# MSE on test:  2.036428717364286
# Non-zero elements:  0
